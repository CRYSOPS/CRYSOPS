# %% [markdown]
# <a href="https://colab.research.google.com/github/CRYSOPS/CRYSOPS/blob/main/scientific_calculator2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

#operations in scientific calculator
def add(a,b):
  return a + b


def subtract(a,b):
  return a - b

def multiply(a,b):
  return a * b

def divide(a,b):
  return a / b

def sqrt(a):
  result = math.sqrt(a)
  return result

def exp(a):
  return a ** 2

def sin(x):
  result = math.sin(x)
  return result

def cos(x):
  result = math.cos(x)
  return result

def tan(x):
  result = math.tan(x)
  return result

#choosing the operations
print ("""
choose a number from the operations
1 - addition(x,y)
2 - subraction (x,y)
3 - multiplication (x,y)
4 - divide (x,y)
5 - square (x)
6 - square root (x)
7 - sin(x)
8 - cos(x)
9 - tan(x)""")
op = int(input('What operation do you want to perform?'))

#calculator script
while op < 10:
  if op == 1:
    print ("enter the parameters")
    x1 = int (input("enter x"))
    y1 = int (input ("enter y"))
    res1 = add(x1, y1)
    print("addition= ", res1)
  elif op == 2:
    x2 = int (input("enter x"))
    y2 = int (input ("enter y"))
    res2 = subtract(x2, y2)
    print("subraction= ", res2)
  elif op == 3:
    x3 = int (input("enter x"))
    y3 = int (input ("enter y"))
    res3 = multiply(x3, y3)
    print("multiplication= ", res3)
  elif op == 4:
    x4 = int (input("enter x"))
    y4 = int (input ("enter y"))
    res4 = divide(x4, y4)
    print("divide= ", res4)
  elif op == 5:
    x5 = int (input("enter x"))
    res5 = exp(x5)
    print("square= ", res5)
  elif op == 6:
    x6 = int (input("enter x"))
    res6 = sqrt(x6)
    print("square root= ", res6)
  elif op == 7:
    x7 = int (input("enter x"))
    res7 = sin(x7)
    print("sin= ", res7)
  elif op == 8:
    x8 = int (input("enter x"))
    res8 = cos(x8)
    print("cos= ", res8)
  elif op == 9:
    x9 = int (input("enter x"))
    res9 = tan(x9)
    print("tan= ", res9)

  else:
    print ('choose another operations')
  
  new = int(input("do you want to continue - (yes - 1), (no - 0) "))
  if new == 1:
    op = int(input("enter operation"))
  elif new == 0:
    print ("thanks for using scientific calculator")
    break
# Out:
# choose a number from the operations
# 1 - addition(x,y)
# 2 - subraction (x,y)
# 3 - multiplication (x,y)
# 4 - divide (x,y)
# 5 - square (x)
# 6 - square root (x)
# 7 - sin(x)
# 8 - cos(x)
# 9 - tan(x)
# What operation do you want to perform?1
# enter the parameters
# enter x10
# enter y20
# addition=  30
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation2
# enter x10
# enter y20
# subraction=  -10
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation3
# enter x10
# enter y20
# multiplication=  200
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation4
# enter x10
# enter y20
# divide=  0.5
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation5
# enter x242
# square=  58564
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation6
# enter x144
# square root=  12.0
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation7
# enter x15
# sin=  0.6502878401571168
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation8
# enter x15
# cos=  -0.7596879128588213
# do you want to continue - (yes - 1), (no - 0) 1
# enter operation9
# enter x15
# tan=  -0.8559934009085187
# do you want to continue - (yes - 1), (no - 0) 0
# thanks for using scientific calculator
